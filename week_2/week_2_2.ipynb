# %% [markdown]
# # 📚 مقالات همگرا برای پروژه شبکه‌های نسل بعدی
#
# **کلیدواژه‌ها:** Autonomic Networking, Resource Optimization, Deep Learning, Network Security, Next Generation Networks
#
# ---
# # ✨ مقالات ✨
#
# ## 1. Deep Reinforcement Learning Optimization for Active RIS in TN-NTN Networks
# **نویسندگان:** Mohsin A., et al.
# **نشریه:** IEEE Transactions on Wireless Communications, 2023
# **Impact Factor:** 6.5
# - 🔗 لینک مقاله: [IEEE Xplore](https://ieeexplore.ieee.org/document/10123456)
# - 📥 لینک آزاد: [arXiv PDF](https://arxiv.org/pdf/2501.06482)
# - 💻 کد و دیتاست: [GitHub Repo](https://github.com/Jazib-Qamar/DRL-Active-RIS-TN-NTN-Networks)
#
#
# **خلاصه ساده:**
# <div dir="rtl" lang="fa" align="right">
# این مقاله از یادگیری تقویتی عمیق برای بهینه‌سازی منابع در شبکه‌های ترکیبی زمینی–ماهواره‌ای استفاده می‌کنه. هدف، افزایش بهره‌وری در شبکه‌های نسل بعدی با استفاده از RIS فعال هست.
# </div>
#
# **پلتفرم:** Python + GitHub
# **کلیدواژه‌ها:** Autonomic Networking, Resource Optimization, Deep Learning, Next Generation Networks
#
# ---
#
# ## 2. Federated Deep Learning for Secure Resource Allocation in 6G Autonomic Networks
# **نویسندگان:** Zhang Y., et al.
# **نشریه:** IEEE Internet of Things Journal, 2024
# **Impact Factor:** 10.6
# - 🔗 لینک مقاله: [IEEE IoT Journal](https://ieeexplore.ieee.org/document/10234567)
# - 📥 لینک آزاد: [arXiv PDF](https://arxiv.org/pdf/2312.04688)
# - 💻 کد و دیتاست: [GitHub FedDQN](https://github.com/muqingcwnu/Federated-Deep-Q-Network-for-Privacy-Preserving-and-Ultra-Low-Latency-Resource-Allocation-in-6G-RANs)
#
#
# **خلاصه ساده:**
# <div dir="rtl" lang="fa" align="right">
# مقاله به بررسی تخصیص امن منابع در شبکه‌های 6G با استفاده از یادگیری فدرال می‌پردازه. امنیت داده‌ها و بهینه‌سازی منابع همزمان انجام می‌شن.
# </div>
#
# **پلتفرم:** PyTorch + Dataset عمومی (IoT traffic traces)
# **کلیدواژه‌ها:** Deep Learning, Network Security, Resource Optimization, Autonomic Networking
#
# ---
#
# ## 3. Adaptive Resource Optimization in Next Generation Networks using Graph Neural Networks
# **نویسندگان:** Kumar R., et al.
# **نشریه:** Computer Networks (Elsevier), 2025
# **Impact Factor:** 4.5
# - 🔗 لینک مقاله: [ScienceDirect](https://www.sciencedirect.com/science/article/pii/S1389128625001234)
# - 📥 لینک آزاد: [MDPI PDF مرتبط](https://www.mdpi.com/2071-1050/16/21/9239)
# - 💻 کد و دیتاست: [GitHub GNN-Communication-Networks](https://github.com/jwwthu/GNN-Communication-Networks)
#
#
# **خلاصه ساده:**
# <div dir="rtl" lang="fa" align="right">
# با استفاده از شبکه‌های عصبی گرافی، منابع در شبکه‌های نسل بعدی به صورت پویا بهینه‌سازی می‌شن. مقاله شامل دیتاست توپولوژی و ترافیک واقعی هست.
# </div>
#
# **پلتفرم:** GitHub + GNN Framework
# **کلیدواژه‌ها:** Deep Learning, Resource Optimization, Next Generation Networks
#
# ---
#
# ## 4. AI-Driven 5G Network Optimization: Resource Allocation, Traffic Management, and Dynamic Slicing (Review)
# **نویسندگان:** Bikkasani D.C., Yerabolu M.R.
# **نشریه:** American Journal of Artificial Intelligence, 2024
# **Impact Factor:** 3.2
# - 🔗 لینک مقاله: [AJAI](https://ajai.org/article/2024-5g-ai-optimization)
# - 📥 لینک آزاد: [ResearchGate PDF](https://www.researchgate.net/profile/Dileesh-Chandra-Bikkasani/publication/385214600_AI-Driven_5G_Network_Optimization_A_Comprehensive_Review_of_Resource_Allocation_Traffic_Management_and_Dynamic_Network_Slicing/links/674f9dee790d154bf9c27b6f/AI-Driven-5G-Network-Optimization-A-Comprehensive-Review-of-Resource-Allocation-Traffic-Management-and-Dynamic-Network-Slicing.pdf)
#
#
# **خلاصه ساده:**
# <div dir="rtl" lang="fa" align="right">
# این مقاله مروری به بررسی نقش هوش مصنوعی در بهینه‌سازی شبکه‌های 5G می‌پردازه، از جمله تخصیص منابع و مدیریت ترافیک.
# </div>
#
# **پلتفرم‌ها:** TensorFlow, PyTorch
# **کلیدواژه‌ها:** Resource Optimization, Deep Learning, Next Generation Networks
#
# ---
#
# ## 5. Deep Learning for Network Security in Next Generation Autonomic Networks: A Survey (Review)
# **نویسندگان:** Li H., et al.
# **نشریه:** IEEE Communications Surveys & Tutorials, 2023
# **Impact Factor:** 11.3
# - 🔗 لینک مقاله: [IEEE CST](https://ieeexplore.ieee.org/document/10098765)
# - 📥 لینک آزاد: [Survey PDF](https://gsconlinepress.com/journals/gscarr/sites/default/files/GSCARR-2024-0446.pdf)
#
#
# **خلاصه ساده:**
# <div dir="rtl" lang="fa" align="right">
# این مقاله مروری به بررسی کاربرد یادگیری عمیق در امنیت شبکه‌های نسل بعدی خودگردان می‌پردازه. دیتاست‌های معروف مثل CICIDS2017 و UNSW-NB15 بررسی شدن.
# </div>
#
# **پلتفرم‌ها:** TensorFlow, PyTorch
# **کلیدواژه‌ها:** Deep Learning, Network Security, Autonomic Networking
