# %% [markdown]
# <div dir="rtl" lang="fa" style="text-align: right; white-space: pre-wrap; font-size: 16px; line-height: 1.8; font-family: 'Vazirmatn', 'Tahoma', sans-serif;">
#
# # 📘 سوالات تستی و تشریحی صفحه تا 60
#
# <div dir="rtl">
# 🧩 سؤالات تستی (چهارگزینه‌ای)
#
# <div dir="rtl">
# 1️⃣ کدام مورد به‌درستی تفاوت بین Packet Switching و Circuit Switching را بیان می‌کند؟
# A) در Packet Switching مسیر از پیش تعیین‌شده است.
# B) در Circuit Switching داده‌ها به بسته‌های جداگانه تقسیم می‌شوند.
# C) در Packet Switching هر بسته ممکن است مسیر متفاوتی طی کند.
# D) در Circuit Switching از پروتکل IP استفاده می‌شود.
# 🟩 پاسخ صحیح: C
#
#
# ---
# <div dir="rtl">
# 2️⃣ در مدل OSI، وظیفه‌ی آدرس‌دهی منطقی و مسیریابی (Routing) بر عهده‌ی کدام لایه است؟
# A) لایه انتقال (Transport)
# B) لایه شبکه (Network)
# C) لایه پیوند داده (Data Link)
# D) لایه فیزیکی (Physical)
# 🟩 پاسخ صحیح: B
# </div>
#
# ---
#
# <div dir="rtl">
# 3️⃣ در ارتباطات شبکه‌ای، وظیفه‌ی ARP (Address Resolution Protocol) چیست؟
# A) ترجمه آدرس IP به آدرس MAC
# B) اختصاص IP به دستگاه‌ها
# C) ایجاد کانال ارتباطی امن
# D) تشخیص خطا در انتقال داده
# 🟩 پاسخ صحیح: A
#
# ---
#
# <div dir="rtl">
# 4️⃣ کدام‌یک از موارد زیر جزء خدمات connection-oriented محسوب می‌شود؟
# A) HTTP
# B) UDP
# C) TCP
# D) ICMP
# 🟩 پاسخ صحیح: C
#
# ---
#
# <div dir="rtl">
# 5️⃣ کدام عبارت درباره‌ی مفهوم Encapsulation صحیح است؟
# A) فرآیندی است که داده‌ها را به بیت تبدیل می‌کند.
# B) اضافه‌کردن هدر و تریلر هر لایه به داده‌ی لایه‌ی بالاتر است.
# C) انتقال داده‌ها بدون استفاده از پروتکل‌هاست.
# D) حذف هدر در مقصد برای افزایش سرعت انتقال است.
# 🟩 پاسخ صحیح: B
#
# ---
#
# <div dir="rtl">
# ✏️سوالات تشریحی :
#
# <div dir="rtl">
# سؤال 1️⃣ : تفاوت دیدگاه "nuts and bolts" و "service view" در تعریف اینترنت چیست؟
# 🔹 پاسخ: دیدگاه nuts and bolts (پیچ و مهره‌ای) به ساختار فیزیکی و فنی اینترنت نگاه می‌کند. در این دیدگاه، اینترنت مجموعه‌ای از دستگاه‌ها، کابل‌ها، مسیریاب‌ها (routers)، سوئیچ‌ها، پروتکل‌ها (مثل TCP/IP) و شبکه‌هایی است که به هم متصل شده‌اند و داده‌ها را جابه‌جا می‌کنند.
# برای مثال، در این دیدگاه گفته می‌شود که «داده از طریق بسته‌های IP بین میزبان‌ها منتقل می‌شود».
# در مقابل، دیدگاه service view (دیدگاه خدماتی) بر خدماتی که اینترنت ارائه می‌دهد تمرکز دارد. در این دیدگاه اینترنت محیطی است که خدماتی مثل وب، ایمیل، انتقال فایل، تماس ویدئویی، یا پیام‌رسانی را به کاربران ارائه می‌دهد، بدون توجه به جزئیات فنی چگونگی انتقال داده.
# به‌عبارت دیگر:
# • nuts and bolts view ⇒ «اینترنت چگونه کار می‌کند»
# • service view ⇒ «اینترنت چه خدمتی ارائه می‌دهد»
#
# ---
#
# <div dir="rtl">
# سؤال 2️⃣ : مفهوم لایه‌بندی در شبکه را توضیح بده و بگو چرا استفاده از مدل‌های لایه‌ای (مثل OSI یا TCP/IP) در طراحی شبکه اهمیت دارد.
# 🔹 پاسخ: لایه‌بندی (Layering) روشی است برای تقسیم عملکردهای پیچیده‌ی شبکه به بخش‌های ساده‌تر و مجزا. هر لایه وظیفه خاصی دارد و تنها با لایه‌ی بالایی و پایینی خود در تعامل است.
# در مدل OSI هفت لایه و در مدل TCP/IP پنج لایه وجود دارد (فیزیکی، پیوند داده، شبکه، انتقال، و کاربرد).
# مزایای لایه‌بندی عبارت‌اند از:
# • سادگی در طراحی و آموزش: هر لایه وظیفه مشخصی دارد و پیچیدگی کلی سیستم کاهش می‌یابد.
# • انعطاف‌پذیری: تغییر یا به‌روزرسانی یک لایه (مثلاً پروتکل انتقال) نیازی به تغییر سایر لایه‌ها ندارد.
# • استانداردسازی: سازمان‌ها و سازندگان تجهیزات مختلف می‌توانند محصولات خود را براساس لایه‌ها طراحی کنند تا با هم سازگار باشند.
# به‌طور خلاصه، لایه‌بندی باعث نظم، سهولت توسعه، و استقلال عملکردی بخش‌های مختلف شبکه می‌شود.
#
# ---
#
# <div dir="rtl">
# سؤال 3️⃣ : نحوه‌ی عملکرد ARP و RARP را در یک شبکه‌ی محلی (LAN) توضیح بده و بیان کن هرکدام در چه شرایطی مورد استفاده قرار می‌گیرند.
# 🔹 پاسخ: در یک شبکه محلی، دستگاه‌ها برای برقراری ارتباط نیاز به دانستن آدرس فیزیکی (MAC Address) مقصد دارند.
# پروتکل ARP (Address Resolution Protocol) وظیفه دارد آدرس IP را به آدرس MAC تبدیل کند.
# فرآیند ARP به این شکل است:
# • میزبان فرستنده در جدول ARP خود جست‌وجو می‌کند تا ببیند آیا MAC مربوط به IP مقصد را دارد یا نه.
# • اگر نداشته باشد، یک پیام ARP Request به کل شبکه ارسال می‌کند (Broadcast).
# • دستگاهی که آن IP را دارد، با ارسال ARP Reply، آدرس MAC خود را اعلام می‌کند.
# • میزبان، آدرس را در جدول خود ذخیره می‌کند تا در آینده مستقیم از آن استفاده کند.
# پروتکل RARP (Reverse ARP) برعکس عمل می‌کند؛ یعنی زمانی استفاده می‌شود که دستگاه فقط آدرس MAC خود را می‌داند و می‌خواهد IP خودش را از سرور شبکه بگیرد (مثلاً در دستگاه‌های بدون دیسک).
# بنابراین:
# • ARP → IP → MAC
# • RARP → MAC → IP
#
# ---
#
# <div dir="rtl">
# سؤال 4️⃣ : تفاوت بین Connection-Oriented Service و Connectionless Service را با ذکر مثال از پروتکل‌های واقعی توضیح بده.
# 🔹 پاسخ: در خدمات Connection-Oriented، قبل از ارسال داده بین دو میزبان، ابتدا یک ارتباط منطقی (Connection) برقرار می‌شود و داده‌ها به ترتیب و با اطمینان منتقل می‌گردند. پروتکل TCP نمونه‌ای از این نوع خدمات است.
# در این روش:
# • ابتدا ارتباط (Handshake سه‌مرحله‌ای) ایجاد می‌شود.
# • داده‌ها شماره‌گذاری و تأیید (ACK) می‌شوند.
# • در صورت بروز خطا، بسته‌ها مجدداً ارسال می‌شوند.
# مثال: بارگذاری صفحات وب، ارسال ایمیل (SMTP)، FTP
# در مقابل، در خدمات Connectionless هیچ ارتباط پایداری پیش از انتقال داده وجود ندارد. هر بسته مستقل ارسال می‌شود و ممکن است ترتیب آن‌ها تغییر کند یا برخی گم شوند. پروتکل UDP نمونه‌ی این نوع است.
# مثال: پخش زنده ویدئو، تماس اینترنتی (VoIP)، بازی‌های آنلاین
# به‌طور خلاصه:
# • TCP → قابل اعتماد ولی کندتر
# • UDP → سریع‌تر ولی بدون اطمینان از تحویل
#
# ---
#
# <div dir="rtl">
# سؤال 5️⃣ : مفهوم Multiplexing و Demultiplexing را در لایه انتقال شرح بده و بگو چرا این دو فرآیند برای برقراری ارتباط بین چند برنامه روی یک دستگاه ضروری‌اند.
# 🔹 پاسخ: در هر میزبان شبکه، چندین برنامه ممکن است به‌طور هم‌زمان از شبکه استفاده کنند (مثلاً مرورگر، پیام‌رسان، و آپدیت سیستم). لایه انتقال وظیفه دارد داده‌ها را بین این برنامه‌ها و لایه شبکه به‌صورت منظم تفکیک و توزیع کند.
# • Multiplexing (چندنشری) : زمانی‌که داده‌های چند برنامه‌ی مختلف باید از طریق یک شبکه ارسال شوند، لایه انتقال هر جریان داده را با شماره‌ی پورت مخصوصش (مثل 80 برای HTTP، 25 برای SMTP) علامت‌گذاری می‌کند و آن‌ها را در قالب یک جریان کلی به لایه پایین‌تر می‌فرستد.
# • Demultiplexing (چندگشایی) : در سمت گیرنده، لایه انتقال بسته‌ها را دریافت می‌کند و براساس شماره‌ی پورت مشخص می‌کند که هر داده متعلق به کدام برنامه است و آن را به همان برنامه تحویل می‌دهد.
# به‌صورت خلاصه:
# Multiplexing ⇒ ترکیب چند جریان خروجی
# Demultiplexing ⇒ جداسازی چند جریان ورودی
# بدون این دو فرآیند، سیستم نمی‌توانست تشخیص دهد هر بسته‌ی دریافتی مربوط به کدام برنامه است و ارتباط بین چند نرم‌افزار به‌طور هم‌زمان ممکن نمی‌شد.
# </div>
